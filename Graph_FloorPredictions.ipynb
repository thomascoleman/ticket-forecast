# %%
# %time from ticketdata.lumberjack import *
# %matplotlib inline
# Out:
# StubHub ticket database exists and is connected!
# starting lumberjack...
# Importing prediction data...
# Still importing...
# Still importing...
# Prediction data imported!
# importing pickles...
# still importing pickles...
# pickles are in!
# 9.02
# CPU times: user 31.1 s, sys: 2.72 s, total: 33.8 s
# Wall time: 35.9 s

# %%
predict_floor(9441890, cutoff=.1, plot=True)
# Out:
# 42.502759821137204

# %%
predict_floor(9441957, plot=True)
# Out:
# 10000

# %%
predict_floor(9441957, plot=True)
# Out:
# 10000
